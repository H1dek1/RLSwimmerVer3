# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../same_analysis/data/test_trained_result.csv')

# %%
df
# Out:
#     trained_params  simulate_params  thousand_reward
# 0              1.0              1.0       354.564472
# 1              1.0              2.0       544.283731
# 2              1.0              3.0       618.725410
# 3              1.0              4.0       615.833867
# 4              1.0              5.0       574.924258
# ..             ...              ...              ...
# 76             9.0              5.0     -1000.343512
# 77             9.0              6.0     -1170.161533
# 78             9.0              7.0     -1300.297079
# 79             9.0              8.0     -1391.209712
# 80             9.0              9.0     -1436.247588
#
# [81 rows x 3 columns]

# %%
trained_values = [2.0, 3.0, 5.0]

# %%
fig, ax = plt.subplots(1,1, figsize=(10,8))
ax.grid()
for trained_value in trained_values:
    df_ = df[df['trained_params'] == trained_value]
    ax.plot(df_['simulate_params'], df_['thousand_reward'])

# %%
df_2 = df[df['trained_params'] == 2]
df_2
# Out:
#     trained_params  simulate_params  thousand_reward
# 9              2.0              1.0       387.609983
# 10             2.0              2.0       690.777378
# 11             2.0              3.0       943.917042
# 12             2.0              4.0      1146.258139
# 13             2.0              5.0      1308.558402
# 14             2.0              6.0      1433.882301
# 15             2.0              7.0      1522.837342
# 16             2.0              8.0      1567.696109
# 17             2.0              9.0      1547.466757

# %%
df_3 = df[df['trained_params'] == 3]
df_3
# Out:
#     trained_params  simulate_params  thousand_reward
# 18             3.0              1.0       300.094169
# 19             3.0              2.0       717.480506
# 20             3.0              3.0      1198.652418
# 21             3.0              4.0      1718.567595
# 22             3.0              5.0      2236.035976
# 23             3.0              6.0      2716.853049
# 24             3.0              7.0      3188.489611
# 25             3.0              8.0      3567.169078
# 26             3.0              9.0      3891.420740
